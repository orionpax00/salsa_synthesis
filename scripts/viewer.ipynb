# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
data_man = np.load("../data/all_asfamc/npsubjects/60/60_01.npy")
data_woman = np.load("../data/all_asfamc/npsubjects/61/61_01.npy")

# %%
fig = plt.figure()
ax = Axes3D(fig)
xm=[]
ym=[]
zm=[]
xw = []
yw = []
zw = []
for i in data_man[0]:
    xm.append(i[0])
    ym.append(i[1])
    zm.append(i[2])
    
for i in data_woman[0]:
    xw.append(i[0])
    yw.append(i[1])
    zw.append(i[2])
plt.plot(zw,xw,yw, "b.") ## plotting order should be Z,X,Y not X,Y,Z
plt.plot(zm,xm,ym, "r.") ## plotting order should be Z,X,Y not X,Y,Z
plt.show()

# %%
data_man.shape
# Out:
# (2242, 31, 3)

# %%
data_man = np.load("../salsa/60/60_01.npy")
data_woman = np.load("../salsa/61_01.npy")

# %%
data_woman.shape
# Out:
# (2242, 21, 3)

# %%
fig = plt.figure()
ax = Axes3D(fig)
xm=[]
ym=[]
zm=[]
xw = []
yw = []
zw = []
for i in data_man[0]:
    xm.append(i[0])
    ym.append(i[1])
    zm.append(i[2])
    
for i in data_woman[0]:
    xw.append(i[0])
    yw.append(i[1])
    zw.append(i[2])
plt.plot(zw,xw,yw, "b.") ## plotting order should be Z,X,Y not X,Y,Z
plt.plot(zm,xm,ym, "r.") ## plotting order should be Z,X,Y not X,Y,Z
plt.show()

# %%
data_loc = os.path.join(os.getcwd(),"salsa") #transformed data location
split = Split(location=data_loc, sequence_length = int(100), overlap = int(0))
train_data = split.split_train()

# %%
train_data.shape
# Out:
# (483, 100, 21, 3)

# %%
test_data = split.split_test()

# %%
test_data.shape
# Out:
# (21, 100, 21, 3)

# %%
data_gen = np.load("image_at_epoch_0005.npy")

# %%
## Building exoskeleton

joint_name = [
                "pelvis",
                "left_hip",
                "left_knee",
                "left_ankle",
                "left_foot",
                "right_hip",
                "right_knee",
                "right_ankle",
                "right_foot",
                "spine",
                "bottom_neck",
                "bottom_head",
                "head_top",
                "left_shoulder",
                "left_elbow",
                "left_waist",
                "left_hand",
                "right_shoulder",
                "right_elbow",
                "right_wrist",
                "right_hand"
            ]

PARENT_LIMBS = {
        "PARENT_LIMBS" : [16, 15, 1, 2, 3, 1, 5, 6, 14, 8, 9, 14, 11, 12, 14, 14, 1, 4, 7, 10, 13],
             "indcies" : [0,1,2,3,4,6,7,8,9,11,13,15,16,17,18,20,21,24,25,27,28],
        }

# %%
connection = [(0,1), (0,1),(0,5), (1,2), (0,9),(2,3), (3,4), (5,6), (6,7), (7,8), (9,10), (10,11),(11,12), (10,17),(10,13), (13,14), (14,15), (15,16),(10,17), (17,18), (18,19), (19,20)]

# %%
arr = []
for i in connection:
    data_point = ([data_woman[0][i[0]][2], data_woman[0][i[1]][2]], [data_woman[0][i[0]][1], data_woman[0][i[1]][1]], [data_woman[0][i[0]][0], data_woman[0][i[1]][0]])
    arr.append(data_point)

# %%
fig = plt.figure()
ax = Axes3D(fig)

xm=[]
ym=[]
zm=[]

for i in data_woman[0]:
    xm.append(i[0])
    ym.append(i[1])
    zm.append(i[2])
    
plt.plot(zm,xm,ym, "r.")

for i in arr:
    plt.plot(i[0],i[2],i[1]) ## plotting order should be Z,X,Y not X,Y,Z
plt.show()

# %%
arr = []
for i in connection:
    data_point = ([data_gen[100][0][i[0]][2], data_gen[100][0][i[1]][2]], [data_gen[0][0][i[0]][1], data_gen[100][0][i[1]][1]], [data_gen[100][0][i[0]][0], data_gen[100][0][i[1]][0]])
    arr.append(data_point)

# %%
fig = plt.figure()
ax = Axes3D(fig)

xm=[]
ym=[]
zm=[]

for i in data_gen[100][0]:
    xm.append(i[0])
    ym.append(i[1])
    zm.append(i[2])
    
plt.plot(zm,xm,ym, "r.")

for i in arr:
    plt.plot(i[0],i[2],i[1]) ## plotting order should be Z,X,Y not X,Y,Z
plt.show()

# %%
for j in range(101):
    fig = plt.figure()
    ax = Axes3D(fig)
    arr = []
    for i in connection:
        data_point = ([data_gen[j][0][i[0]][2], data_gen[j][0][i[1]][2]], [data_gen[j][0][i[0]][1], data_gen[j][0][i[1]][1]], [data_gen[j][0][i[0]][0], data_gen[j][0][i[1]][0]])
        arr.append(data_point)

    xm=[]
    ym=[]
    zm=[]

    for i in data_gen[j][0]:
        xm.append(i[0])
        ym.append(i[1])
        zm.append(i[2])

    plt.plot(zm,xm,ym, "r.")

    for i in arr:
        plt.plot(i[0],i[2],i[1]) ## plotting order should be Z,X,Y not X,Y,Z
    plt.savefig('img/image{:04d}.png'.format(j))
    plt.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-db26a16e87d5> in <module>
#      20     for i in arr:
#      21         plt.plot(i[0],i[2],i[1]) ## plotting order should be Z,X,Y not X,Y,Z
# ---> 22     plt.savefig('img/image{:04d}.png'.format(j))
#      23     plt.close()
#
# d:\projects\motion_gen\tfp\env\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     720 def savefig(*args, **kwargs):
#     721     fig = gcf()
# --> 722     res = fig.savefig(*args, **kwargs)
#     723     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     724     return res
#
# d:\projects\motion_gen\tfp\env\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
# ...

# %%
## transform walk for noise

data = np.load("D:\\projects\\motion_gen\\tfp\\data\\all_asfamc\\npsubjects\\02\\02_01.npy")
_onlyjoint_data = []
for frame in data:
    _onlyjoint_data.append(frame[np.asarray([0,1,2,3,4,6,7,8,9,11,13,15,16,17,18,20,21,24,25,27,28])])
# _data = transform.transform(np.asarray(_onlyjoint_data))
_data = _onlyjoint_data

np.save(os.path.join("noise.npy"),_data)

# %%
data = np.load("noise.npy")

# %%
data.shape
# Out:
# (343, 21, 3)
