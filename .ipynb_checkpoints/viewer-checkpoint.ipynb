# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
dat = np.load("01_01.npy")

# %%
dat[0].shape[0]
# Out:
# 3

# %%
from tfp.utils.transform_data import Transformation

# %%
data = []

for x,y,z in zip(dat[0][0][0:21],dat[0][1][0:21],dat[0][2][0:21]):
    dump = []
    dump.append(x)
    dump.append(y)
    dump.append(z)
    
    data.append(dump)
    
# for x,y,z in zip(dat[1][0][0:21],dat[1][1][0:21],dat[1][2][0:21]):
#     dump = []
#     dump.append(x)
#     dump.append(y)
#     dump.append(z)
    
#     data.append(dump)
    
trans = Transformation(21)
t_data = trans.transform(np.asarray(data).reshape(1,np.asarray(data).shape[0],np.asarray(data).shape[1]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-9a59ea5a456b> in <module>
#      18
#      19 trans = Transformation(21)
# ---> 20 t_data = trans.transform(np.asarray(data).reshape(1,np.asarray(data).shape[0],np.asarray(data).shape[1]))
#
# D:\projects\motion_gen\tfp\tfp\utils\transform_data.py in transform(self, joints, head_length)
#     135         sph_rel_joints = self. _cart2sph(rel_joints_xyz)
#     136         # normalization of limb lengths
# --> 137         fixed_limb_lengths = head_length * self.limb_ratios
#     138         # Replace the limb lengths with unnormalized limb lengths
#     139         sph_rel_joints[:, 0] = fixed_limb_lengths
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
type(np.asarray(data).reshape(1,np.asarray(data).shape[0],np.asarray(data).shape[1])[0][0][0])
# Out:
# numpy.float64

# %%
fig = plt.figure()
ax = Axes3D(fig)
plt.plot(dat[0][2], dat[0][0], dat[0][1], 'b.')
plt.show()

# %%
len(dat[0][2])
# Out:
# 31

# %%
dat = np.load("02_01.npy")

# %%
dat.shape
# Out:
# (343, 31, 3)

# %%
dat[0]
# Out:
# array([[ 10.4194    ,  16.7048    , -30.1003    ],
#        [ 11.83680548,  14.85386112, -29.12548846],
#        [ 10.75368516,   8.35960014, -25.34185373],
#        [ 10.16512146,   1.16637494, -24.33488644],
#        [ 10.27828613,   1.35207448, -22.12375522],
#        [ 10.3691466 ,   1.90725333, -21.16398711],
#        [  8.62170067,  15.02287093, -29.68287145],
#        [  9.71019503,   7.68002251, -31.25306914],
#        [ 10.86592318,   1.15822855, -34.11527745],
#        [ 10.76031881,   0.18911936, -32.10147239],
#        [ 10.66796857,  -0.05441752, -31.01661046],
#        [ 10.31724075,  18.76163002, -30.08404503],
#        [ 10.12162095,  20.80663514, -29.87223276],
#        [  9.98658731,  22.85342303, -29.60891319],
#        [  9.86084892,  24.4226532 , -29.60935695],
#        [  9.93328597,  25.97125103, -29.81591013],
#        [ 10.05402417,  27.59111346, -29.89940531],
#        [ 13.46547447,  23.97529925, -29.42760057],
# ...

# %%
fig = plt.figure()
ax = Axes3D(fig)
x=[]
y=[]
z=[]
for i in dat[0]:
    x.append(i[0])
    y.append(i[1])
    z.append(i[2])
plt.plot(z,x,y,"b.")
plt.show()

# %%
for i in dat[0]:
    print(i[0])
# Out:
# 10.4194
# 11.836805479108595
# 10.753685157798866
# 10.165121459060378
# 10.27828612804672
# 10.36914660192986
# 8.621700674867892
# 9.710195029695587
# 10.865923177537184
# 10.76031881290632
# 10.667968565166058
# 10.317240749646862
# 10.121620950596789
# 9.98658730928329
# 9.860848917771534
# 9.933285968042279
# 10.054024167402346
# 13.465474469660569
# 13.249192995874605
# 13.811801696761968
# 14.093106047209124
# 14.343373068769706
# 14.487061751643498
# 14.131110711172063
# 6.472264764140805
# 5.792003223954188
# 5.846011270565929
# 5.873015374150066
# 5.681420452408125
# 5.592475578004742
# 6.08947185109539
